# %%
import pandas as pd
import numpy as np

# %%
#Read the neighbourhood data
#CSV downloaded from: https://data.edmonton.ca/Geospatial-Boundaries/City-of-Edmonton-Neighbourhood-Boundaries/jfvj-x253
df = pd.read_csv('NEIGHBOURHOODS_SHAPE_2.csv')
pd.options.display.max_columns = 75
pd.options.display.max_rows = 50
df = df.replace({'\)':''}, regex=True) #clean up the trailing parentheses
df = df.replace(r'^\s*$', np.nan, regex=True) #replace empty cells with NaN
df.tail(6)
# Out:
#                                 NAME NUMBER  AREA_KM2  \
# 395  Winterburn Industrial Area West  4,670  4.340206
# 396                        Woodcroft  3,450  1.291675
# 397         Yellowhead Corridor East  1,270  1.430509
# 398         Yellowhead Corridor West  1,280  1.164862
# 399                             York  2,720  1.188834
# 400            Youngstown Industrial  4,660  0.483841
#
#                                   the_geom  \
# 395   -113.7137069813738 53.54119743232371
# 396  -113.56570359212786 53.56908921523379
# 397  -113.44511314016736 53.58363617864351
# 398  -113.5371377601615 53.583475118730924
# 399  -113.42930360518905 53.60689611803747
# 400  -113.60517306486945 53.55594869912666
#
#                                   Unnamed: 4  \
# 395   -113.71370760207304 53.541197440926986
# 396     -113.56580890235425 53.5693389584453
# 397    -113.44508586880151 53.58364163250797
# 398   -113.53774365225462 53.583475287927754
# 399   -113.42567596887035 53.606890645566516
# 400      -113.60599403987788 53.554934332901
#
#                                   Unnamed: 5  \
# 395    -113.71370784198724 53.54130710804342
# 396    -113.56579181475891 53.57036767647372
# 397    -113.44505863846918 53.58364728768554
# 398     -113.5378908603555 53.58347532857805
# 399   -113.42367066492281 53.606890904998366
# 400     -113.606018307744 53.554904347597464
#
#                                   Unnamed: 6  \
# 395    -113.71372333852358 53.54852761843802
# 396    -113.56137885746547 53.57031018169771
# 397   -113.44503145065639 53.583653143867586
# 398     -113.53862777044307 53.5834755405471
# 399    -113.42281575158667 53.60688785857662
# 400   -113.60841683818273 53.551940495442764
#
#                                   Unnamed: 7  \
# 395     -113.71373418628055 53.5543789475511
# 396   -113.55800123993943 53.570297480049135
# 397    -113.44500451679102 53.58365915307917
# 398    -113.53936466004365 53.58347573861976
# 399    -113.41988914790257 53.60688397593324
# 400    -113.60891317465548 53.55126606828388
#
#                                  Unnamed: 8  \
# 395    -113.71373424081307 53.5544083626072
# 396   -113.55633527461696 53.57029308690464
# 397    -113.4449776276975 53.58366535955785
# 398   -113.53951964627667 53.58347577967383
# 399   -113.41762997156476 53.60691094105942
# 400   -113.61021842410561 53.54949236878544
#
#                                  Unnamed: 9  \
# 395    -113.7135514609591 53.55440962292505
# 396   -113.55465131750458 53.57029147125062
# 397   -113.44495078482063 53.58367176297014
# 398    -113.54039760016218 53.5834760083613
# 399    -113.4183859998353 53.60508050121137
# 400   -113.61099423066275 53.54843805004795
#
#                                  Unnamed: 10  \
# 395    -113.71335496158552 53.55441097753121
# 396    -113.55127362562511 53.57027613603173
# 397     -113.44403671343107 53.5836653970449
# 398    -113.54076140008767 53.58347609845516
# 399     -113.4185558832971 53.60439220768963
# 400   -113.61266655987812 53.546320590181715
#
#                                  Unnamed: 11  \
# 395   -113.70432945471343 53.554521572201786
# 396    -113.5493791743313 53.570281133679174
# 397   -113.44312861861931 53.583658866824756
# 398    -113.54093670833872 53.58347615685732
# 399    -113.4185107111145 53.603787683764146
# 400   -113.61387272569779 53.544975476564616
#
#                                  Unnamed: 12  \
# 395    -113.70432698657969 53.55217554195141
# 396   -113.54945741196873 53.568433149418524
# 397    -113.44293404850572 53.58365862007449
# 398    -113.54103408991948 53.58347618039961
# 399    -113.41825551970486 53.60340242453437
# 400    -113.61491771166081 53.54379066938818
#
#                                  Unnamed: 13  \
# 395    -113.70432312757849 53.54850803743901
# 396   -113.54946863322378 53.567377334682156
# 397    -113.44294100842086 53.58245755222603
# 398    -113.54117231787278 53.58347692129351
# 399   -113.41778125628659 53.602978593756745
# 400    -113.61542618177259 53.54349632385622
#
#                                  Unnamed: 14  \
# 395     -113.7012908775292 53.54850156156312
# 396   -113.54946913649222 53.566828798184204
# 397    -113.4430945402353 53.582361736721644
# 398    -113.54117377472534 53.58374909542216
# 399   -113.41690243269639 53.602334552980466
# 400    -113.61588011220147 53.54403636354326
#
#                                  Unnamed: 15  \
# 395    -113.69102345618403 53.54847906303887
# 396    -113.54951729312066 53.56629891125997
# 397   -113.44533326252039 53.580963749624104
# 398    -113.54117469777496 53.58392154186199
# 399    -113.41956000541973 53.60006173350326
# 400    -113.61600384949641 53.54438773466811
#
#                                  Unnamed: 16  \
# 395     -113.68971275978713 53.5484761324873
# 396     -113.5496756698002 53.56593857024467
# 397     -113.44569873718784 53.5807354818508
# 398    -113.54103263859353 53.58392084835367
# 399     -113.4211682013131 53.59877590339341
# 400   -113.61599207405563 53.544771174454446
#
#                                  Unnamed: 17  \
# 395    -113.68926217192407 53.54847511039551
# 396    -113.55027946406182 53.56521745276689
# 397     -113.4489846484463 53.57868298269149
# 398     -113.54093188976708 53.5839208582865
# 399   -113.42202769821853 53.599027299403986
# 400   -113.61585754595677 53.545243052095444
#
#                                  Unnamed: 18  \
# 395   -113.68924848780534 53.548475083522746
# 396    -113.55128597686385 53.56403878813229
# 397   -113.44914069610196 53.578585661854525
# 398    -113.54073089033628 53.58392087846317
# 399    -113.42348980963034 53.59938486266435
# 400    -113.61553706759996 53.54631553014665
#
#                                  Unnamed: 19  \
# 395    -113.68902545536466 53.54847611429638
# 396    -113.55140195953693 53.56381457400519
# 397   -113.44933020212294 53.578467473460606
# 398    -113.54039878724966 53.58392111312882
# 399    -113.42450901687415 53.59949898554447
# 400    -113.61522375773524 53.54737382816777
#
#                                  Unnamed: 20  \
# 395    -113.68902671864868 53.54822414531695
# 396    -113.5514493245212 53.563556284330986
# 397   -113.44963874427071 53.578275044157245
# 398    -113.53951843294315 53.58392115374127
# 399   -113.42634002216238 53.599514076299016
# 400     -113.6151837155239 53.54863122497673
#
#                                  Unnamed: 21  \
# 395    -113.68895380075573 53.54715370309393
# 396   -113.55144453204794 53.563242240667286
# 397     -113.44990333429749 53.5781100347209
# 398    -113.53936593008078 53.58392105235895
# 399   -113.43058459785972 53.599520676998864
# 400    -113.61518260612782 53.54893625438977
#
#                                  Unnamed: 22  \
# 395    -113.6884909908678 53.544157812222494
# 396   -113.55142167732241 53.560494901630285
# 397   -113.44995734579355 53.578076350947285
# 398    -113.53804482794176 53.58392118950954
# 399   -113.43515332970992 53.599505946710515
# 400    -113.61519627601555 53.55324972161165
#
#                                  Unnamed: 23  \
# 395    -113.68854044854602 53.54116027101294
# 396    -113.55139820578599 53.55892093319117
# 397   -113.44999700025622 53.578051524819216
# 398   -113.53789382998443 53.583921210889535
# 399     -113.4388475415604 53.59960877232711
# 400   -113.61522759100002 53.555962132045856
#
#                                  Unnamed: 24  \
# 395      -113.688712234685 53.54116048546604
# 396     -113.5523366964004 53.55884052477757
# 397    -113.45003660583845 53.57802662078538
# 398    -113.53774198990844 53.58392137848342
# 399    -113.44030162385923 53.59962567445268
# 400   -113.60823014145156 53.555961924397906
#
#                                  Unnamed: 25  \
# 395     -113.6887752076214 53.54116056401793
# 396     -113.5555180436973 53.55882965625608
# 397   -113.45007616238716 53.578001638942006
# 398    -113.53596690976983 53.58392514848347
# 399     -113.4429352160769 53.59965624208794
# 400    -113.60517306486945 53.55594869912666
#
#                                 Unnamed: 26  \
# 395    -113.6889558771257 53.54116078919936
# 396    -113.5656764469879 53.55882317155061
# 397   -113.45011554402083 53.57797665930831
# 398    -113.5359669700094 53.58401576867374
# 399   -113.44283392450546 53.60221019846539
# 400                                     NaN
#
#                                  Unnamed: 27  \
# 395    -113.69195251742308 53.54116448432238
# 396    -113.56580346434838 53.55936376737418
# 397   -113.45015487662968 53.577951602551686
# 398   -113.53596702014332 53.584119458448036
# 399    -113.44280850323656 53.60484387506708
# 400                                      NaN
#
#                                  Unnamed: 28  \
# 395   -113.69443455706057 53.541167488045204
# 396   -113.56582726431859 53.560488925955774
# 397    -113.45019416006265 53.57792646876836
# 398     -113.53596724986924 53.5847206684743
# 399    -113.44024576462726 53.60484827549193
# 400                                      NaN
#
#                                  Unnamed: 29  \
# 395    -113.69999705947416 53.54119542497207
# 396    -113.56585821129846 53.56288087861487
# 397    -113.45022514788849 53.57790657800851
# 398   -113.53596746996482 53.584871038499976
# 399   -113.43957028566555 53.604845114169045
# 400                                      NaN
#
#                                  Unnamed: 30  \
# 395   -113.71119008749925 53.541196320768044
# 396     -113.565837617876 53.565217893254136
# 397      -113.4502561043815 53.5778866385196
# 398    -113.53596749312382 53.58491627676913
# 399    -113.43882468810212 53.60484162025545
# 400                                      NaN
#
#                                  Unnamed: 31  \
# 395     -113.7135347805939 53.54119637571177
# 396    -113.56571530636843 53.56580671579763
# 397   -113.45028702946506 53.577866650351005
# 398   -113.53596751628257 53.584961515037946
# 399    -113.43732508489542 53.60483885503693
# 400                                      NaN
#
#                                  Unnamed: 32  \
# 395     -113.7137069813738 53.54119743232371
# 396   -113.56570814639265 53.567793504890886
# 397   -113.45031784444855 53.577846664626954
# 398    -113.53596749425222 53.58496151505108
# 399    -113.43589776962592 53.60483719437338
# 400                                      NaN
#
#                                  Unnamed: 33  \
# 395                                      NaN
# 396    -113.56570359212786 53.56908921523379
# 397    -113.45034862803027 53.57782663056921
# 398   -113.53505209695611 53.584962055788175
# 399    -113.43528759233462 53.60483650647798
# 400                                      NaN
#
#                                 Unnamed: 34  \
# 395                                     NaN
# 396                                     NaN
# 397   -113.45037938013441 53.57780654822712
# 398   -113.53349147422611 53.58495668792045
# 399   -113.43493127989782 53.60487157184509
# 400                                     NaN
#
#                                  Unnamed: 35  \
# 395    -113.71376027021192 53.56872686292721
# 396                                      NaN
# 397    -113.45060757613345 53.57765546104929
# 398    -113.53196853694409 53.58495959000062
# 399   -113.43459704473403 53.604938951099975
# 400                                      NaN
#
#                                  Unnamed: 36  ... Unnamed: 805 Unnamed: 806  \
# 395    -113.71376458193701 53.56977048836801  ...          NaN          NaN
# 396                                      NaN  ...          NaN          NaN
# 397    -113.45083386613447 53.57750153384339  ...          NaN          NaN
# 398    -113.53040264026875 53.58495759950642  ...          NaN          NaN
# 399   -113.43435004040775 53.605023593882215  ...          NaN          NaN
# 400                                      NaN  ...          NaN          NaN
#
#     Unnamed: 807 Unnamed: 808 Unnamed: 809 Unnamed: 810 Unnamed: 811  \
# 395          NaN          NaN          NaN          NaN          NaN
# 396          NaN          NaN          NaN          NaN          NaN
# 397          NaN          NaN          NaN          NaN          NaN
# 398          NaN          NaN          NaN          NaN          NaN
# 399          NaN          NaN          NaN          NaN          NaN
# 400          NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 812 Unnamed: 813 Unnamed: 814 Unnamed: 815 Unnamed: 816  \
# 395          NaN          NaN          NaN          NaN          NaN
# 396          NaN          NaN          NaN          NaN          NaN
# 397          NaN          NaN          NaN          NaN          NaN
# 398          NaN          NaN          NaN          NaN          NaN
# 399          NaN          NaN          NaN          NaN          NaN
# 400          NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 817 Unnamed: 818 Unnamed: 819 Unnamed: 820 Unnamed: 821  \
# 395          NaN          NaN          NaN          NaN          NaN
# 396          NaN          NaN          NaN          NaN          NaN
# 397          NaN          NaN          NaN          NaN          NaN
# 398          NaN          NaN          NaN          NaN          NaN
# 399          NaN          NaN          NaN          NaN          NaN
# 400          NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 822 Unnamed: 823 Unnamed: 824 Unnamed: 825 Unnamed: 826  \
# 395          NaN          NaN          NaN          NaN          NaN
# 396          NaN          NaN          NaN          NaN          NaN
# 397          NaN          NaN          NaN          NaN          NaN
# 398          NaN          NaN          NaN          NaN          NaN
# 399          NaN          NaN          NaN          NaN          NaN
# 400          NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 827 Unnamed: 828 Unnamed: 829 Unnamed: 830 Unnamed: 831  \
# 395          NaN          NaN          NaN          NaN          NaN
# 396          NaN          NaN          NaN          NaN          NaN
# 397          NaN          NaN          NaN          NaN          NaN
# 398          NaN          NaN          NaN          NaN          NaN
# 399          NaN          NaN          NaN          NaN          NaN
# 400          NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 832 Unnamed: 833 Unnamed: 834 Unnamed: 835 Unnamed: 836  \
# 395          NaN          NaN          NaN          NaN          NaN
# 396          NaN          NaN          NaN          NaN          NaN
# 397          NaN          NaN          NaN          NaN          NaN
# 398          NaN          NaN          NaN          NaN          NaN
# 399          NaN          NaN          NaN          NaN          NaN
# 400          NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 837 Unnamed: 838 Unnamed: 839 Unnamed: 840 Unnamed: 841
# 395          NaN          NaN          NaN          NaN          NaN
# 396          NaN          NaN          NaN          NaN          NaN
# 397          NaN          NaN          NaN          NaN          NaN
# 398          NaN          NaN          NaN          NaN          NaN
# 399          NaN          NaN          NaN          NaN          NaN
# 400          NaN          NaN          NaN          NaN          NaN
#
# [6 rows x 842 columns]

# %%
#Separate the Latitude and Longitude coordinates into their own dataframes to compute neighbourhood centroids

dfLat= df.iloc[:,3].str.split(' ').str[1].astype(float).to_frame() #later columns have an inital space so initialize the first column
dfLong= df.iloc[:,3].str.split(' ').str[0].astype(float).to_frame() #later columns have an inital space so initialize the first column

for i in range(4,len(dfGPS.columns)):       
        dfLat[i]=df.iloc[:,i].str.split(' ').str[2]
        dfLong[i]=df.iloc[:,i].str.split(' ').str[1]
        
#convert to float
dfLat = dfLat.apply(pd.to_numeric)
dfLong = dfLong.apply(pd.to_numeric)

# %%
#some long's get parsed wrong so just remove them for the average calculation
for i in range(4,len(dfGPS.columns)):       
        dfLong[i].loc[(dfLong[i] > 1.0)] = np.nan

# %%
#Compute the latitude and longitude centroids, then create a new dataframe with only the needed columns

dfLat['mean'] = dfLat.mean(axis=1, skipna = True)
dfLong['mean'] = dfLong.mean(axis=1, skipna = True)

dfEdmonton = df[['NAME']]
dfEdmonton['Latitude'] = dfLat[['mean']]
dfEdmonton['Longitude'] = dfLong[['mean']]
dfEdmonton.rename(columns={'NAME':'Neighborhood'}, inplace = True)
dfEdmonton.tail(6)
# Out:
# <ipython-input-621-e7aae74bdeb5>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfEdmonton['Latitude'] = dfLat[['mean']]
# <ipython-input-621-e7aae74bdeb5>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfEdmonton['Longitude'] = dfLong[['mean']]
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:4290: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#                         Neighborhood   Latitude   Longitude
# 395  Winterburn Industrial Area West  53.553555 -113.701469
# 396                        Woodcroft  53.565543 -113.557051
# 397         Yellowhead Corridor East  53.581239 -113.459361
# 398         Yellowhead Corridor West  53.582963 -113.529320
# 399                             York  53.603784 -113.429378
# 400            Youngstown Industrial  53.549405 -113.612230

# %%
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

import folium # map rendering library

import requests
import json
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# %%
address = 'Edmonton, AB'

geolocator = Nominatim(user_agent="to_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Edmonton are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Edmonton are 53.535411, -113.507996.

# %%
# create map of Edmonton using latitude and longitude values
map_edmonton = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, neighborhood in zip(dfEdmonton['Latitude'], dfEdmonton['Longitude'], dfEdmonton['Neighborhood']):
    label = '{}'.format(neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_edmonton)  

map_edmonton
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Explore the neighborhoods in Foursquare

CLIENT_ID = 'DI1IROLVKDMIMPBFVKAOIDWSEJDVGIKEFDQW4QDEVY3PSVKE' # your Foursquare ID
CLIENT_SECRET = '5CLO0VAMN11K1LQL2S35NKALY02AZ2BTWM4UAON2LQNBS2WF' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: DI1IROLVKDMIMPBFVKAOIDWSEJDVGIKEFDQW4QDEVY3PSVKE
# CLIENT_SECRET:5CLO0VAMN11K1LQL2S35NKALY02AZ2BTWM4UAON2LQNBS2WF

# %%
LIMIT = 20 # limit of number of venues returned by Foursquare API
radius = 1000 # define radius in metres
section = 'coffee' #search for only coffee shops
numCoffeeShopsList = []
topCoffeeShopIdList = []

for i in range(0,len(dfEdmonton)):

    neighborhood_latitude = dfEdmonton.loc[i, 'Latitude'] # neighborhood latitude value
    neighborhood_longitude = dfEdmonton.loc[i, 'Longitude'] # neighborhood longitude value
    neighborhood_name = dfEdmonton.loc[i, 'Neighborhood'] # neighborhood name

    # create URL
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&section={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        neighborhood_latitude, 
        neighborhood_longitude, 
        radius, 
        LIMIT,
        section)
    
    results = requests.get(url).json()
     
    venues = results['response']['groups'][0]['items']
    
    nearby_venues = json_normalize(venues) # flatten JSON

    # filter columns
    filtered_columns = ['venue.name', 'venue.id', 'venue.location.lat', 'venue.location.lng']
    try:
        nearby_venues = nearby_venues.loc[:, filtered_columns]     
        nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns] # clean columns
        topCoffeeShopIdList.append(nearby_venues.loc[0,'id'])
    except KeyError:
        topCoffeeShopIdList.append(-1)

    numCoffeeShopsList.append(len(nearby_venues))
# Out:
# <ipython-input-411-a746075690cb>:28: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   nearby_venues = json_normalize(venues) # flatten JSON

# %%
len(topCoffeeShopIdList) #check to make sure all locations were checked
# Out:
# 401

# %%
len(numCoffeeShopsList)
# Out:
# 401

# %%
import time
topCoffeeShopRatings = []

for i in topCoffeeShopIdList:
    if (i != -1): #
        venue_id = i

        # create URL
        url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
        url # display URL
               
        results = requests.get(url).json()
        print (results)
        
        try:
            rating = results['response']['venue']['rating']
            topCoffeeShopRatings.append(rating)
            print (rating)
        except KeyError:
            topCoffeeShopRatings.append(np.nan)
            print (np.nan)
        
    else:
        topCoffeeShopRatings.append(np.nan) #where no coffee shop rating available
        print (np.nan)
        
    time.sleep(1)
# Out:
# {'meta': {'code': 200, 'requestId': '5f2757668f44ac7ed5821f9d'}, 'response': {'venue': {'id': '4baff56af964a5205d2e3ce3', 'name': 'Tim Hortons', 'contact': {'phone': '7804771115', 'formattedPhone': '(780) 477-1115', 'twitter': 'timhortons'}, 'location': {'address': '3522 118th Ave Nw', 'crossStreet': 'beside Shell', 'lat': 53.570728407218226, 'lng': -113.39624404907227, 'labeledLatLngs': [{'label': 'display', 'lat': 53.570728407218226, 'lng': -113.39624404907227}], 'postalCode': 'T5W 0Z4', 'cc': 'CA', 'city': 'Edmonton', 'state': 'AB', 'country': 'Canada', 'formattedAddress': ['3522 118th Ave Nw (beside Shell)', 'Edmonton AB T5W 0Z4', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/tim-hortons/4baff56af964a5205d2e3ce3', 'categories': [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d148941735', 'name': 'Donut Shop', 'pluralName': 'Donut Shops', 'shortName': 'Donuts', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 1}, 'url': 'https://www.timhortons.ca/store-locator/store/restaurant_68643', 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 4, 'groups': [{'type': 'others', 'count': 4, 'items': [{'id': '578349401', 'firstName': 'Donald', 'lastName': 'G', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/blank_boy.png', 'default': True}}, {'id': '7057604', 'firstName': 'Timothy', 'lastName': 'A', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/ZZCEVMXXK5ESBVMQ.jpg'}}, {'id': '7057604', 'firstName': 'Timothy', 'lastName': 'A', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/ZZCEVMXXK5ESBVMQ.jpg'}}, {'id': '27818918', 'firstName': 'Chris', 'lastName': 'W', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/27818918-TPFUTAE32UAERRVM.jpg'}}]}], 'summary': '4 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.2, 'ratingColor': 'FFC800', 'ratingSignals': 8, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 4, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 4, 'items': [{'id': '5a2f1126b3d8e2273c2297ba', 'createdAt': 1513034022, 'source': {'name': 'Yext Yext', 'url': 'http://yext.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/87388367_fQoA-etAwGH2--ZNAx7rGZbVZM9FPM3B_azfg69tkpE.jpg', 'width': 670, 'height': 670, 'user': {'id': '87388367', 'firstName': 'Yext', 'lastName': 'Y', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/blank_boy.png', 'default': True}}, 'visibility': 'public'}, {'id': '5022be06e4b02b10e097bef9', 'createdAt': 1344454150, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/vsLbTQR4yRBrlZdtz8fJMmUolhh2Q9hOTIOgr6O6wds.jpg', 'width': 405, 'height': 540, 'user': {'id': '32102984', 'firstName': 'Clinton', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/BR323IKJFKOGPMS0.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'description': "Located at 3522 118th Ave Nw, Edmonton, AB, Tim Hortons is the perfect place to go for great-tasting, freshly brewed coffee. Our coffee is made with 100% Arabica beans, sourced from the world's most renowned growing regions...", 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1269822826, 'tips': {'count': 1, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 1, 'items': [{'id': '561c6ed7498e4ce22b7a24aa', 'createdAt': 1444703959, 'text': 'It has great coffee', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/561c6ed749 ...
# 6.2
# {'meta': {'code': 200, 'requestId': '5f275725ba97fe39f1b6804d'}, 'response': {'venue': {'id': '5bd745124c954c002c107a4c', 'name': 'Starbucks', 'contact': {'phone': '7804789834', 'formattedPhone': '(780) 478-9834', 'twitter': 'starbucks', 'facebook': '22092443056', 'facebookUsername': 'Starbucks', 'facebookName': 'Starbucks'}, 'location': {'address': '16815 127 St NW', 'lat': 53.63035, 'lng': -113.54049, 'labeledLatLngs': [{'label': 'display', 'lat': 53.63035, 'lng': -113.54049}], 'postalCode': 'T6V 0T1', 'cc': 'CA', 'city': 'Edmonton', 'state': 'AB', 'country': 'Canada', 'formattedAddress': ['16815 127 St NW', 'Edmonton AB T6V 0T1', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/starbucks/5bd745124c954c002c107a4c', 'categories': [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d16d941735', 'name': 'Café', 'pluralName': 'Cafés', 'shortName': 'Café', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}}], 'verified': True, 'stats': {'tipCount': 1}, 'url': 'http://www.starbucks.com', 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 0, 'groups': []}, 'dislike': False, 'ok': False, 'rating': 6.7, 'ratingColor': 'FFC800', 'ratingSignals': 1, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 2, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 2, 'items': [{'id': '5357c2c6498ec084ef63a3bc', 'createdAt': 1398260422, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/7624952_BO3FVlVXvfWOgtDrdujIKA-zN34qzaHsdZChx8m_pBo.jpg', 'width': 960, 'height': 720, 'user': {'id': '7624952', 'firstName': 'Steve', 'lastName': 'B', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/7624952-UKV0KA152NDJDH0V.jpg'}}, 'visibility': 'public'}, {'id': '55622671498e15288fdd4172', 'createdAt': 1432495729, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/38253577_GPCPOwi8Q6bKbisYzCVBa8JHVsWiDv8y5C7wITX0Yro.jpg', 'width': 1440, 'height': 1920, 'user': {'id': '38253577', 'firstName': 'Cory', 'lastName': 'S', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/38253577_j3Bq2IUE_JWX8pPxzNaLSNU9n3S2nRdW1Eu0uwDTkiMMR2gFkAaC2yS5f2Lb6KU8PrYMdU360.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'description': 'At Starbucks Coffee Canada, we’re passionate about coffee & customers. It’s why our baristas handcraft delicious coffee & espresso beverages That’s #coffeelove', 'page': {'pageInfo': {'links': {'count': 1, 'items': [{'url': 'http://www.starbucks.com'}]}}, 'user': {'id': '551920070', 'firstName': 'Starbucks - CAN', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/551920070_um9x5Iwo_eUJoprQacVwKAdzG6Pax-I3Ct8uNaY-flDQxBI3bIAsCXYVcn_g4RuBO5f3zdp_B.png'}, 'type': 'chain', 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1540834578, 'tips': {'count': 1, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 1, 'items': [{'id': '52eb148411d230f52c37dc10', 'createdAt': 1391137924, 'text': 'This is my new favourite location - not as much seating inside but AWESOME baristas!!!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/52eb148411d230f52c37dc10', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '8304609', 'firstName': 'Christine', 'lastName': 'M', 'pho ...
# 6.7
# {'meta': {'code': 200, 'requestId': '5f27559d0070593f9d400796'}, 'response': {'venue': {'id': '4c229b3b99282d7f986d67b0', 'name': 'The Carrot Community Arts Coffeehouse', 'contact': {'phone': '7804711580', 'formattedPhone': '(780) 471-1580', 'twitter': 'artsontheave', 'facebook': '134358063379101', 'facebookUsername': 'TheCarrotCoffeehouse', 'facebookName': 'The Carrot Community Arts Coffeehouse'}, 'location': {'address': '9351 118 Ave NW', 'lat': 53.570275525983156, 'lng': -113.48555858294544, 'labeledLatLngs': [{'label': 'display', 'lat': 53.570275525983156, 'lng': -113.48555858294544}], 'postalCode': 'T5G 0N3', 'cc': 'CA', 'city': 'Edmonton', 'state': 'AB', 'country': 'Canada', 'formattedAddress': ['9351 118 Ave NW', 'Edmonton AB T5G 0N3', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/artsontheave', 'categories': [{'id': '4bf58dd8d48988d16d941735', 'name': 'Café', 'pluralName': 'Cafés', 'shortName': 'Café', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}, 'primary': True}], 'verified': True, 'stats': {'tipCount': 7}, 'url': 'http://www.thecarrot.ca', 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 17, 'groups': [{'type': 'others', 'count': 17, 'items': []}], 'summary': '17 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.2, 'ratingColor': '73CF42', 'ratingSignals': 22, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 8, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 8, 'items': [{'id': '52cf18d5498e578c9a35b594', 'createdAt': 1389304021, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/105990_ntsReCAB41mb7UmXGWp3fgVyfOih8Vx6xr5XTCemVJ0.jpg', 'width': 720, 'height': 960, 'user': {'id': '105990', 'firstName': 'Jerry', 'lastName': 'A', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/105990-SBIFWPRSFNTJVYHF.jpg'}}, 'visibility': 'public'}, {'id': '5706a100498e61cac0fbe99e', 'createdAt': 1460052224, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/1761755_wmnUe2udYba7KsbQ9tC4BGCSynyEaxp39818OD08-0U.jpg', 'width': 1440, 'height': 1440, 'user': {'id': '1761755', 'firstName': 'Elena', 'lastName': 'P', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/DB30UYNWLGIDIO43.jpg'}}, 'visibility': 'public'}]}]}, 'venuePage': {'id': '41957205'}, 'reasons': {'count': 0, 'items': []}, 'description': 'Volunteer run & fueled by great coffee we offer: a meeting place for friends, live performance, open mic, workshops, rentals, a gallery, and artisan gifts.', 'storeId': '', 'page': {'user': {'id': '41957205', 'firstName': 'The Carrot Community Arts Coffeehouse', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/41957205-IA3SA3RPOFFGYCCD.png'}, 'type': 'venuePage', 'venue': {'id': '4c229b3b99282d7f986d67b0'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1277336379, 'tips': {'count': 7, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 7, 'items': [{'id': '4e60f2cf7d8b854088fc0e39', 'createdAt': 1314976463, 'text': 'Arts on the avenue!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4e60f2cf7d8b854088fc0e39', 'lang': 'en', 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'id': '50172939', 'firstName': 'George', 'lastName': 'E', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/RPEPV54X1KRWSYSA.jpg'}}, {'id': '39239541', 'firstName': 'Michelle', 'lastName': 'E', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/HU4IV2QALRNID0ZL.jpg'}}, {'id': '41957205', 'firstNam ...
# 8.2
# {'meta': {'code': 200, 'requestId': '5f2756908b9c0f542657ebab'}, 'response': {'venue': {'id': '4c810e4bd8086dcb04fc6852', 'name': 'Tim Hortons', 'contact': {'phone': '7804475586', 'formattedPhone': '(780) 447-5586', 'twitter': 'timhortons'}, 'location': {'address': '15606 111th Ave Nw', 'crossStreet': '156 St', 'lat': 53.559622113213806, 'lng': -113.59139420092106, 'labeledLatLngs': [{'label': 'display', 'lat': 53.559622113213806, 'lng': -113.59139420092106}], 'postalCode': 'T5M 2R7', 'cc': 'CA', 'city': 'Edmonton', 'state': 'AB', 'country': 'Canada', 'formattedAddress': ['15606 111th Ave Nw (156 St)', 'Edmonton AB T5M 2R7', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/tim-hortons/4c810e4bd8086dcb04fc6852', 'categories': [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 2}, 'url': 'https://www.timhortons.ca/store-locator/store/restaurant_67076', 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': [{'id': '465430547', 'firstName': 'Abdul Khaleel', 'lastName': 'M', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/465430547_EGkYSL16_41-a2s2iTHSPKa_A0QREHzRUVGIb6Rlv-1biilzij4D9oRvsKLtxmV3weRUTtNTu.jpg'}}]}], 'summary': '1 Like'}, 'dislike': False, 'ok': False, 'rating': 5.9, 'ratingColor': 'FF9600', 'ratingSignals': 5, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 4, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 4, 'items': [{'id': '5cdb50511543c7002c9b2e3d', 'createdAt': 1557876817, 'source': {'name': 'Swarm for Android', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/9811632_fQT9izzERjdDQcGRCNpHfDoUJZqADBzQulrhaalGFBk.jpg', 'width': 1068, 'height': 1900, 'user': {'id': '9811632', 'firstName': 'Don', 'lastName': 'P', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/9811632-R0KQG5TZ0KMXNLQV.jpg'}}, 'visibility': 'public'}, {'id': '5a2f0c5e5f68b95154394cd4', 'createdAt': 1513032798, 'source': {'name': 'Yext Yext', 'url': 'http://yext.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/87388367_fQoA-etAwGH2--ZNAx7rGZbVZM9FPM3B_azfg69tkpE.jpg', 'width': 670, 'height': 670, 'user': {'id': '87388367', 'firstName': 'Yext', 'lastName': 'Y', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/blank_boy.png', 'default': True}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'description': "Located at 15606 111th Ave Nw, Edmonton, AB, Tim Hortons is the perfect place to go for great-tasting, freshly brewed coffee. Our coffee is made with 100% Arabica beans, sourced from the world's most renowned growing regions...", 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1283526219, 'tips': {'count': 2, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 2, 'items': [{'id': '4f3bf54be4b04bfb5a87c34a', 'createdAt': 1329329483, 'text': 'Is Arlene S. the mayor of all Tim Hortons in the west end!?', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4f3bf54be4b04bfb5a87c34a', 'lang': 'en', 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': [{'id': '24823869', 'firstName': 'Trevor', 'lastName': 'M', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/SG4R22MTGQLVSZGK.jpg'}}]}], 'summary': '1 like'}, 'logView': True, 'agreeCount': 1, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '18654737', 'firstName': 'Aaron', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/TMESZ5DAMIXPJXI2.jpg'}}}, {'id': '4e9ef0fc6da161b08dc453c8', 'createdAt': 1319039228,  ...
# 5.9
# {'meta': {'code': 200, 'requestId': '5f27571df025076ada968f94'}, 'response': {'venue': {'id': '4c3baa6fa9509c74c2d6385b', 'name': 'Primrose Red Rooster Food Store', 'contact': {}, 'location': {'address': '8458 182 ST', 'lat': 53.51768381476165, 'lng': -113.63767755147742, 'labeledLatLngs': [{'label': 'display', 'lat': 53.51768381476165, 'lng': -113.63767755147742}], 'postalCode': 'T5T 1Y7', 'cc': 'CA', 'city': 'Edmonton', 'state': 'AB', 'country': 'Canada', 'formattedAddress': ['8458 182 ST', 'Edmonton AB T5T 1Y7', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/primrose-red-rooster-food-store/4c3baa6fa9509c74c2d6385b', 'categories': [{'id': '4bf58dd8d48988d16f941735', 'name': 'Hot Dog Joint', 'pluralName': 'Hot Dog Joints', 'shortName': 'Hot Dogs', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/hotdog_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}}, {'id': '4bf58dd8d48988d1c4941735', 'name': 'Restaurant', 'pluralName': 'Restaurants', 'shortName': 'Restaurant', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 1}, 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 0, 'groups': []}, 'dislike': False, 'ok': False, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 0, 'groups': []}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1278978671, 'tips': {'count': 1, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 1, 'items': [{'id': '4dbdd2fa43a1d8504bafe2d6', 'createdAt': 1304285946, 'text': 'Really cheap slurpees and you can get vanilla soft serve on top for 75 cents.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4dbdd2fa43a1d8504bafe2d6', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '3100013', 'firstName': 'Jackie', 'lastName': 'G', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/OB4M5E3SEWIJQT2V.jpg'}}}]}]}, 'shortUrl': 'http://4sq.com/abuXVA', 'timeZone': 'America/Edmonton', 'listed': {'count': 0, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 0, 'items': []}]}, 'seasonalHours': [], 'pageUpdates': {'count': 0, 'items': []}, 'inbox': {'count': 0, 'items': []}, 'attributes': {'groups': [{'type': 'price', 'name': 'Price', 'summary': '$', 'count': 1, 'items': [{'displayName': 'Price', 'displayValue': '$', 'priceTier': 1}]}]}}}}
# nan
# {'meta': {'code': 200, 'requestId': '5f27588e7455323d640626ed'}, 'response': {'venue': {'id': '5aca1dccf62e097e2bc4c5c0', 'name': 'Tim Hortons', 'contact': {'phone': '8255109899', 'formattedPhone': '(825) 510-9899'}, 'location': {'address': '361 Allard Blvd Sw', 'lat': 53.397025318061736, 'lng': -113.52906837960313, 'labeledLatLngs': [{'label': 'display', 'lat': 53.397025318061736, 'lng': -113.52906837960313}], 'postalCode': 'T6W 0J2', 'cc': 'CA', 'city': 'Edmonton', 'state': 'AB', 'country': 'Canada', 'formattedAddress': ['361 Allard Blvd Sw', 'Edmonton AB T6W 0J2', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/tim-hortons/5aca1dccf62e097e2bc4c5c0', 'categories': [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 1}, 'url': 'https://www.timhortons.ca/store-locator/store/restaurant_74829', 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'id': '53158107', 'firstName': 'Tarah', 'lastName': 'P', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/G4K0NIYHDZEBK0A2.jpg'}}, {'id': '534000584', 'firstName': 'Jesse', 'lastName': 'C', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/blank_boy.png', 'default': True}}, {'id': '465430547', 'firstName': 'Abdul Khaleel', 'lastName': 'M', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/465430547_EGkYSL16_41-a2s2iTHSPKa_A0QREHzRUVGIb6Rlv-1biilzij4D9oRvsKLtxmV3weRUTtNTu.jpg'}}]}], 'summary': '3 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.6, 'ratingColor': 'FFC800', 'ratingSignals': 4, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 1, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 1, 'items': [{'id': '5aca1dcddd70c50891e36210', 'createdAt': 1523195341, 'source': {'name': 'Yext Yext', 'url': 'http://yext.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/87388367_fQoA-etAwGH2--ZNAx7rGZbVZM9FPM3B_azfg69tkpE.jpg', 'width': 670, 'height': 670, 'user': {'id': '87388367', 'firstName': 'Yext', 'lastName': 'Y', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/blank_boy.png', 'default': True}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'description': "Located at 361 Allard Blvd Sw, Edmonton, AB, Tim Hortons is the perfect place to go for great-tasting, freshly brewed coffee. Our coffee is made with 100% Arabica beans, sourced from the world's most renowned growing regions...", 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1523195340, 'tips': {'count': 1, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 1, 'items': [{'id': '5d5facd98ed88000071d2d62', 'createdAt': 1566551257, 'text': 'Open 24hrs', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5d5facd98ed88000071d2d62', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '465430547', 'firstName': 'Abdul Khaleel', 'lastName': 'M', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/465430547_EGkYSL16_41-a2s2iTHSPKa_A0QREHzRUVGIb6Rlv-1biilzij4D9oRvsKLtxmV3weRUTtNTu.jpg'}}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'https://4sq.com/2IAUJK2', 'timeZone': 'America/Edmonton', 'listed': {'count': 0, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 0, 'items': []}]}, 'hours': {'status': 'Open until 11:00 PM', 'richStatus': {'entities': [], 'text': 'Open until 11:00 PM'}, 'isOpen': True, 'isLocalHoliday': False, 'dayData': [], 'timeframes': [{'days': 'Mon–Sun', 'includesToday': True, 'open' ...
# 6.6
# {'meta': {'code': 200, 'requestId': '5f2755ef4411af61b86baa15'}, 'response': {'venue': {'id': '4b05cf32f964a520b0e322e3', 'name': 'High Voltage Food & Coffee Bar', 'contact': {'phone': '7804373202', 'formattedPhone': '(780) 437-3202'}, 'location': {'address': '10387 63 Ave.', 'lat': 53.49967437884996, 'lng': -113.49715817703527, 'labeledLatLngs': [{'label': 'display', 'lat': 53.49967437884996, 'lng': -113.49715817703527}], 'postalCode': 'T6H 1P2', 'cc': 'CA', 'city': 'Edmonton', 'state': 'AB', 'country': 'Canada', 'formattedAddress': ['10387 63 Ave.', 'Edmonton AB T6H 1P2', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/high-voltage-food--coffee-bar/4b05cf32f964a520b0e322e3', 'categories': [{'id': '4bf58dd8d48988d16d941735', 'name': 'Café', 'pluralName': 'Cafés', 'shortName': 'Café', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 8}, 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 8, 'groups': [{'type': 'others', 'count': 8, 'items': [{'id': '65434528', 'firstName': 'Klint', 'lastName': 'K', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/MOXY4WXARHEHEOUW.jpg'}}, {'id': '2638240', 'firstName': 'Eldon', 'lastName': 'K', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/2638240-1KGX4ON332YENHU3.jpg'}}]}], 'summary': '8 Likes'}, 'dislike': False, 'ok': False, 'rating': 5.7, 'ratingColor': 'FF9600', 'ratingSignals': 20, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 4, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 4, 'items': [{'id': '5d631e934f6b660008eeea14', 'createdAt': 1566776979, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/13294354_XneCh7f59PnHl-ZD-HvVDifDxy53ntoNxjdVXiYPe-E.jpg', 'width': 1920, 'height': 1440, 'user': {'id': '13294354', 'firstName': 'Myra', 'lastName': 'M', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/R03ZTM4JKCBDXWQE.jpg'}}, 'visibility': 'public'}, {'id': '58ab5279d4ab73762463d27f', 'createdAt': 1487622777, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/26182764_iC8PEFHQH16VBePmhXiu9t6wOu6kq1QtPfXspNV0FDU.jpg', 'width': 1440, 'height': 1920, 'user': {'id': '26182764', 'firstName': 'Scott (@SQLSocialite)', 'lastName': 'S', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/2YT1JM1XUFLN0PYI.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1258671922, 'tips': {'count': 8, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 8, 'items': [{'id': '55d79466498e3841b99c89b9', 'createdAt': 1440191590, 'text': "The old guy behind the counter refused to serve me coffee. I thought a coffee bar would serve coffee, right? Presently not... Don't waste your time.", 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/55d79466498e3841b99c89b9', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '19646388', 'firstName': 'Sig', 'lastName': 'K', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/U5DIUZ0NIPRY44OZ.jpg'}}}, {'id': '53ec4634498e1f82b83d5b84', 'createdAt': 1407993396, 'text': 'The donairs are among the best in Edmonton — fresh, and definitely not questionable like many donair joints.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/53ec4634498e1f82b83d5b84', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '2638240', 'firstName': 'Eldon', 'lastName' ...
# 5.7
# {'meta': {'code': 200, 'requestId': '5f275700b746232b300dae83'}, 'response': {'venue': {'id': '4f4957fce4b0e7e90fb46782', 'name': 'Starbucks', 'contact': {'phone': '7804364064', 'formattedPhone': '(780) 436-4064', 'twitter': 'starbucks', 'facebook': '22092443056', 'facebookUsername': 'Starbucks', 'facebookName': 'Starbucks'}, 'location': {'address': '5110 Windermere Blvd NW, Safeway Grocery Store', 'crossStreet': 'inside Safeway', 'lat': 53.435027, 'lng': -113.599883, 'labeledLatLngs': [{'label': 'display', 'lat': 53.435027, 'lng': -113.599883}], 'postalCode': 'T6W 0H7', 'cc': 'CA', 'city': 'Edmonton', 'state': 'AB', 'country': 'Canada', 'formattedAddress': ['5110 Windermere Blvd NW, Safeway Grocery Store (inside Safeway)', 'Edmonton AB T6W 0H7', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/starbucks/4f4957fce4b0e7e90fb46782', 'categories': [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d16d941735', 'name': 'Café', 'pluralName': 'Cafés', 'shortName': 'Café', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}}], 'verified': True, 'stats': {'tipCount': 0}, 'url': 'http://www.starbucks.com', 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 4, 'groups': [{'type': 'others', 'count': 4, 'items': [{'id': '48760980', 'firstName': 'Francisco', 'lastName': 'A', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/OWHHVJYW4YVA1IQR.jpg'}}, {'id': '40223982', 'firstName': 'Gayle', 'lastName': 'B', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/TUHKGRQIXASFQCET.jpg'}}, {'id': '17845846', 'firstName': 'Kelli', 'lastName': 'S', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/F5A4ZT5K3KWHEWTS.jpg'}}, {'id': '2383646', 'firstName': 'Paul', 'lastName': 'O', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/2383646-J3CJOL32CBV4OECL.jpg'}}]}], 'summary': '4 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.8, 'ratingColor': 'FFC800', 'ratingSignals': 5, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 1, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 1, 'items': [{'id': '54c5655c498e9b880040f3b3', 'createdAt': 1422222684, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/5262389_ZTDcr3CgrHrycSX13JFD7bxjfIo_2uoPsrDslwEMMAM.jpg', 'width': 1440, 'height': 1920, 'user': {'id': '5262389', 'firstName': 'Cindy', 'lastName': 'G', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/LIUPZD1L4FLEMUUQ.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'description': 'At Starbucks Coffee Canada, we’re passionate about coffee & customers. It’s why our baristas handcraft delicious coffee & espresso beverages That’s #coffeelove', 'page': {'pageInfo': {'links': {'count': 1, 'items': [{'url': 'http://www.starbucks.com'}]}}, 'user': {'id': '551920070', 'firstName': 'Starbucks - CAN', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/551920070_um9x5Iwo_eUJoprQacVwKAdzG6Pax-I3Ct8uNaY-flDQxBI3bIAsCXYVcn_g4RuBO5f3zdp_B.png'}, 'type': 'chain', 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1330206716, 'tips': {'count': 0, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 0, 'items': []}]}, 'shortUrl': 'http://4sq.com/yshqtF', 'timeZone': 'America/Edmonton', 'listed': {'count': 0, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 0, 'items': []}]}, 'hours': {'status': ...
# 6.8
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# {'meta': {'code': 200, 'requestId': '5f2755c8fe1f6657f64555be'}, 'response': {'venue': {'id': '4d5194537ee1a35d3e289134', 'name': '7-Eleven', 'contact': {'phone': '7804590533', 'formattedPhone': '(780) 459-0533', 'twitter': '7elevencanada', 'facebook': '238658479819278', 'facebookUsername': '7ElevenCanadaStAlbert24357', 'facebookName': '7-Eleven Canada'}, 'location': {'address': '23B Akins Drive', 'lat': 53.630843411673666, 'lng': -113.5928859576343, 'labeledLatLngs': [{'label': 'display', 'lat': 53.630843411673666, 'lng': -113.5928859576343}], 'postalCode': 'T8N 3B3', 'cc': 'CA', 'city': 'St. Albert', 'state': 'AB', 'country': 'Canada', 'formattedAddress': ['23B Akins Drive', 'St. Albert AB T8N 3B3', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/7eleven/4d5194537ee1a35d3e289134', 'categories': [{'id': '4d954b0ea243a5684a65b473', 'name': 'Convenience Store', 'pluralName': 'Convenience Stores', 'shortName': 'Convenience Store', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d16d941735', 'name': 'Café', 'pluralName': 'Cafés', 'shortName': 'Café', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}}, {'id': '52f2ab2ebcbc57f1066b8b56', 'name': 'ATM', 'pluralName': 'ATMs', 'shortName': 'ATM', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_', 'suffix': '.png'}}], 'verified': True, 'stats': {'tipCount': 0}, 'url': 'http://t.co/p1Yxhabwq2', 'likes': {'count': 0, 'groups': []}, 'dislike': False, 'ok': False, 'rating': 6.3, 'ratingColor': 'FFC800', 'ratingSignals': 1, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 6, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 6, 'items': [{'id': '5ec8b7c4fadd010008510153', 'createdAt': 1590212548, 'source': {'name': 'Yext Yext', 'url': 'http://yext.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/87388367_fXsVkoJT8CenBId4Epe4VI0L0FUdxChHMabTf1MjRjU.png', 'width': 540, 'height': 540, 'user': {'id': '87388367', 'firstName': 'Yext', 'lastName': 'Y', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/blank_boy.png', 'default': True}}, 'visibility': 'public'}, {'id': '5ec8b7c3f85acd0008144808', 'createdAt': 1590212547, 'source': {'name': 'Yext Yext', 'url': 'http://yext.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/87388367_J3P_CfoBj9RWpmb9vY0MGXLBPfkoXu_WxNtpy7dx_eQ.png', 'width': 515, 'height': 397, 'user': {'id': '87388367', 'firstName': 'Yext', 'lastName': 'Y', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/blank_boy.png', 'default': True}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'description': "At 7-Eleven in St Albert, we never close. Which is why we pride ourselves on being your neighbourhood go-to store - 24/7/365. Drop in for all your delicious wants and your tasty needs. We're home to everything you would expect from a convenience store and so much more...", 'storeId': '24357', 'page': {'pageInfo': {'links': {'count': 1, 'items': [{'url': 'http://t.co/p1Yxhabwq2'}]}}, 'user': {'id': '216484915', 'firstName': '7-Eleven Canada', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/216484915-0HIOMUYAKHEEO5F0.jpg'}, 'type': 'chain', 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1297192019, 'tips': {'count': 0, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 0, 'items': []}]}, 'shortUrl': 'http://4sq.com/i9aWen', 'timeZone': 'America/Edmonton', 'listed': {'count': 0, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 0, 'items': []}]}, 'hours': {'status': 'Open', 'richStatus': {'entities': [], 'te ...
# 6.3
# nan
# {'meta': {'code': 200, 'requestId': '5f27579dcc2d4f2e20e91140'}, 'response': {'venue': {'id': '59d1327c95d9860bceeb3b78', 'name': 'Awake Coffee House', 'contact': {}, 'location': {'address': '11029 9 Ave NW', 'crossStreet': '111 St. NW', 'lat': 53.439067, 'lng': -113.517579, 'labeledLatLngs': [{'label': 'display', 'lat': 53.439067, 'lng': -113.517579}], 'postalCode': 'T6J 5R9', 'cc': 'CA', 'city': 'Edmonton', 'state': 'AB', 'country': 'Canada', 'formattedAddress': ['11029 9 Ave NW (111 St. NW)', 'Edmonton AB T6J 5R9', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/awake-coffee-house/59d1327c95d9860bceeb3b78', 'categories': [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d10f951735', 'name': 'Pharmacy', 'pluralName': 'Pharmacies', 'shortName': 'Pharmacy', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 2}, 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 4, 'groups': [{'type': 'others', 'count': 4, 'items': [{'id': '6811031', 'firstName': 'Spencer', 'lastName': 'S', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/6811031_apJlJidb_xxthFo3tbFUnM4576cJc3E-wJi5GDHkETzL-52zQ2R3jVuniKCKITc-eSaPahjSB.jpg'}}, {'id': '9033080', 'firstName': 'Richard', 'lastName': 'F', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/VOZDH2WQQPTHWQPM.jpg'}}, {'id': '3150372', 'firstName': 'Adrian', 'lastName': 'B', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/XN5X0P2U3KXN1RUA.jpg'}}, {'id': '120675', 'firstName': 'Lonnie', 'lastName': 'S', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/120675-W52RB1USUPMI4YZ0.jpg'}}]}], 'summary': '4 Likes'}, 'dislike': False, 'ok': False, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 9, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 9, 'items': [{'id': '5bd32341b37e2b002c0665d4', 'createdAt': 1540563777, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/6811031__-yBvegTKECmxZuDyB0ylFbSJasndv6idVDKeTxEtMM.jpg', 'width': 1440, 'height': 1920, 'user': {'id': '6811031', 'firstName': 'Spencer', 'lastName': 'S', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/6811031_apJlJidb_xxthFo3tbFUnM4576cJc3E-wJi5GDHkETzL-52zQ2R3jVuniKCKITc-eSaPahjSB.jpg'}}, 'visibility': 'public'}, {'id': '5a075170bed483485c03f4da', 'createdAt': 1510429040, 'source': {'name': 'Foursquare for Android', 'url': 'https://foursquare.com/download/#/android'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/3150372_2w-qxonwQgzxsRvdPEeHO_vLUvNuYOBCezpNQDuAq6Y.jpg', 'width': 5312, 'height': 2988, 'user': {'id': '3150372', 'firstName': 'Adrian', 'lastName': 'B', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/XN5X0P2U3KXN1RUA.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1506882172, 'tips': {'count': 2, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 2, 'items': [{'id': '5bd36cc6dee7700039df935c', 'createdAt': 1540582598, 'text': 'Great coffee. Friendly customer service. Lovely place!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5bd36cc6dee7700039df935c', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '6811031', 'firstName': 'Spencer', 'lastName': 'S', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/6811031_apJlJidb_xxthF ...
# nan
# nan
# {'meta': {'code': 200, 'requestId': '5f27575fe9a64d4c6eb24b47'}, 'response': {'venue': {'id': '4b0ecf24f964a5205b5b23e3', 'name': 'Tim Hortons', 'contact': {'phone': '7804449339', 'formattedPhone': '(780) 444-9339', 'twitter': 'timhortons'}, 'location': {'address': '18314 Lessard Rd', 'crossStreet': "near Sobey's", 'lat': 53.4862277796862, 'lng': -113.64149987697596, 'labeledLatLngs': [{'label': 'display', 'lat': 53.4862277796862, 'lng': -113.64149987697596}], 'postalCode': 'T6M 2W8', 'cc': 'CA', 'city': 'Edmonton', 'state': 'AB', 'country': 'Canada', 'formattedAddress': ["18314 Lessard Rd (near Sobey's)", 'Edmonton AB T6M 2W8', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/tim-hortons/4b0ecf24f964a5205b5b23e3', 'categories': [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d148941735', 'name': 'Donut Shop', 'pluralName': 'Donut Shops', 'shortName': 'Donuts', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 5}, 'url': 'https://www.timhortons.ca/store-locator/store/restaurant_68454', 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 9, 'groups': [{'type': 'others', 'count': 9, 'items': [{'id': '534000584', 'firstName': 'Jesse', 'lastName': 'C', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/blank_boy.png', 'default': True}}, {'id': '730932', 'firstName': 'Kevin', 'lastName': 'C', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/730932-AXP2V4SL4BBEMMK2.jpg'}}]}], 'summary': '9 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.6, 'ratingColor': 'FFC800', 'ratingSignals': 14, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 16, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 16, 'items': [{'id': '51b95bcc498ee72bd46bc8ec', 'createdAt': 1371102156, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/51084010_dLoNjwmrMZl0CE6nFHmoATQcZ2Ka6cTGOBHxPFOXk3E.jpg', 'width': 717, 'height': 959, 'user': {'id': '51084010', 'firstName': 'Bonnie', 'lastName': 'S', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/51084010_u4d9fB0s_haO86n8b4ioWGDbnOeJs41VeUU7ohYzQkH2bd1uilO0vZa5Sz7ytf2D19oxgUabr.jpg'}}, 'visibility': 'public'}, {'id': '51dbfdb6498ed64a13097ab8', 'createdAt': 1373371830, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/51084010_PIU1QP4-sPn_dTdXaidyJM_GtPGDJHHxcSPpzpaAbSU.jpg', 'width': 640, 'height': 960, 'user': {'id': '51084010', 'firstName': 'Bonnie', 'lastName': 'S', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/51084010_u4d9fB0s_haO86n8b4ioWGDbnOeJs41VeUU7ohYzQkH2bd1uilO0vZa5Sz7ytf2D19oxgUabr.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'description': "Located at 18314 Lessard Rd, Edmonton, AB, Tim Hortons is the perfect place to go for great-tasting, freshly brewed coffee. Our coffee is made with 100% Arabica beans, sourced from the world's most renowned growing regions...", 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1259261732, 'tips': {'count': 5, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 5, 'items': [{'id': '4de54a73e4cde71744a557c1', 'createdAt': 1306872435, 'text': 'They have Coldstone Creamery at this location. Yum!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4de54a73e4cde71744a557c1', 'lang': 'en', 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'item ...
# 6.6
# {'meta': {'code': 200, 'requestId': '5f275773780c33707107e612'}, 'response': {'venue': {'id': '4c114c9772caa593e4465da4', 'name': 'Tim Hortons', 'contact': {'phone': '5874993925', 'formattedPhone': '(587) 499-3925', 'twitter': 'timhortons'}, 'location': {'address': '6110 Currents Dr', 'crossStreet': 'Walmart', 'lat': 53.4380698, 'lng': -113.6002044, 'labeledLatLngs': [{'label': 'display', 'lat': 53.4380698, 'lng': -113.6002044}], 'postalCode': 'T6W 0L7', 'cc': 'CA', 'city': 'Edmonton', 'state': 'AB', 'country': 'Canada', 'formattedAddress': ['6110 Currents Dr (Walmart)', 'Edmonton AB T6W 0L7', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/tim-hortons/4c114c9772caa593e4465da4', 'categories': [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 3}, 'url': 'https://www.timhortons.ca/store-locator/store/restaurant_68873', 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 5, 'groups': [{'type': 'others', 'count': 5, 'items': [{'id': '32139766', 'firstName': 'Jacob', 'lastName': 'G', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/5XXS3OW4B54BIKTS.jpg'}}, {'id': '1463380', 'firstName': 'Jonathan', 'lastName': 'M', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/BWUZWC2VPW5MHENF.jpg'}}, {'id': '61391330', 'firstName': 'Frank', 'lastName': 'H', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/0NYOY0WLE3IVXKWE.jpg'}}, {'id': '43483197', 'firstName': 'George', 'lastName': 'S', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/FAYPMHLYY5T5XCWX.jpg'}}]}], 'summary': '5 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.4, 'ratingColor': 'FFC800', 'ratingSignals': 7, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 4, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 4, 'items': [{'id': '51aa8523498ed9fd8abd0d3d', 'createdAt': 1370129699, 'source': {'name': 'Foursquare for Android', 'url': 'https://foursquare.com/download/#/android'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/57589890_Sge-aGpLCmn3CgVxsBMyy_IXo6T4fDR8PMZQXOOTBW4.jpg', 'width': 960, 'height': 473, 'user': {'id': '57589890', 'firstName': 'Ruby', 'lastName': 'R', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/SIFWPBOXCMW2HMQ5.jpg'}}, 'visibility': 'public'}, {'id': '5a2f11c4c824ae2d215bc9ef', 'createdAt': 1513034180, 'source': {'name': 'Yext Yext', 'url': 'http://yext.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/87388367_fQoA-etAwGH2--ZNAx7rGZbVZM9FPM3B_azfg69tkpE.jpg', 'width': 670, 'height': 670, 'user': {'id': '87388367', 'firstName': 'Yext', 'lastName': 'Y', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/blank_boy.png', 'default': True}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'description': "Located at 6110 Currents Dr, Edmonton, AB, Tim Hortons is the perfect place to go for great-tasting, freshly brewed coffee. Our coffee is made with 100% Arabica beans, sourced from the world's most renowned growing regions...", 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1276202135, 'tips': {'count': 3, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 3, 'items': [{'id': '4ded1b7b1520a72c5deddc66', 'createdAt': 1307384699, 'text': '"don\'t settle with someone who only buy you a coffee, be with someone who can make you a coffee"', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4ded1b7b1520a72c5deddc66', 'lang': 'en', 'likes': {'count': 2, 'groups': [{'type': 'others', 'count': 2, 'items': [{'id': '28219403', 'firstName': 'Alan', 'lastName': 'I' ...
# 6.4
# ...
# 8.0
# {'meta': {'code': 200, 'requestId': '5f275735880aab311d249581'}, 'response': {'venue': {'id': '4c76937d66be6dcb6d7ec30f', 'name': 'Van Houtte Coffee', 'contact': {}, 'location': {'address': '7620 Yellowhead Tr.', 'lat': 53.582895, 'lng': -113.458773, 'labeledLatLngs': [{'label': 'display', 'lat': 53.582895, 'lng': -113.458773}], 'cc': 'CA', 'city': 'Edmonton', 'state': 'AB', 'country': 'Canada', 'formattedAddress': ['7620 Yellowhead Tr.', 'Edmonton AB', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/van-houtte-coffee/4c76937d66be6dcb6d7ec30f', 'categories': [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 1}, 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 0, 'groups': []}, 'dislike': False, 'ok': False, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 0, 'groups': []}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1282839421, 'tips': {'count': 1, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 1, 'items': [{'id': '4f2be3f0e4b09e391d258e97', 'createdAt': 1328276464, 'text': 'Twitchy shops here lol', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4f2be3f0e4b09e391d258e97', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '20848154', 'firstName': 'Ryan', 'lastName': 'A', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/K1CFVZP4WDJHQ2ZP.jpg'}}}]}]}, 'shortUrl': 'http://4sq.com/9g1KGa', 'timeZone': 'America/Edmonton', 'listed': {'count': 1, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 1, 'items': [{'id': '4f28757ae4b0b50174ff0c84', 'name': 'The roof', 'description': '', 'type': 'others', 'user': {'id': '20848154', 'firstName': 'Ryan', 'lastName': 'A', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/K1CFVZP4WDJHQ2ZP.jpg'}}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/brotherinblue/list/the-roof', 'canonicalUrl': 'https://foursquare.com/brotherinblue/list/the-roof', 'createdAt': 1328051578, 'updatedAt': 1333777307, 'followers': {'count': 0}, 'listItems': {'count': 5, 'items': [{'id': 'v4c76937d66be6dcb6d7ec30f', 'createdAt': 1328051600}]}}]}]}, 'seasonalHours': [], 'pageUpdates': {'count': 0, 'items': []}, 'inbox': {'count': 0, 'items': []}, 'attributes': {'groups': [{'type': 'price', 'name': 'Price', 'summary': '$', 'count': 1, 'items': [{'displayName': 'Price', 'displayValue': '$', 'priceTier': 1}]}]}}}}
# nan
# {'meta': {'code': 200, 'requestId': '5f2758a97b92c177789dca75'}, 'response': {'venue': {'id': '4b60949af964a520aaee29e3', 'name': '7-Eleven', 'contact': {'phone': '7804532611', 'formattedPhone': '(780) 453-2611', 'twitter': '7elevencanada', 'facebook': '150995614930414', 'facebookUsername': '7ElevenCanadaEdmonton25120', 'facebookName': '7-Eleven Canada'}, 'location': {'address': '12707 127th Street', 'lat': 53.58543919772389, 'lng': -113.54064258188828, 'labeledLatLngs': [{'label': 'display', 'lat': 53.58543919772389, 'lng': -113.54064258188828}], 'postalCode': 'T5L 1A6', 'cc': 'CA', 'city': 'Edmonton', 'state': 'AB', 'country': 'Canada', 'formattedAddress': ['12707 127th Street', 'Edmonton AB T5L 1A6', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/7eleven/4b60949af964a520aaee29e3', 'categories': [{'id': '4d954b0ea243a5684a65b473', 'name': 'Convenience Store', 'pluralName': 'Convenience Stores', 'shortName': 'Convenience Store', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d16d941735', 'name': 'Café', 'pluralName': 'Cafés', 'shortName': 'Café', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}}, {'id': '4bf58dd8d48988d1c7941735', 'name': 'Snack Place', 'pluralName': 'Snack Places', 'shortName': 'Snacks', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_', 'suffix': '.png'}}], 'verified': True, 'stats': {'tipCount': 1}, 'url': 'http://t.co/p1Yxhabwq2', 'likes': {'count': 4, 'groups': [{'type': 'others', 'count': 4, 'items': [{'id': '27688989', 'firstName': 'MO', 'lastName': 'Z', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/27688989_W5SAHSGT__cX3l_Lv1q-B0K9ef4Ub-4__fEkc_1zZZ3UCXopyXbiVlMaYz9VxT6Tx7uWEKLQo.jpg'}}, {'id': '4114778', 'firstName': 'Bunny', 'lastName': 'B', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/4114778_1Ud59u13_wz2sxrSySZLaX9xhVxN_eJWeC9dtBUxFs6fQFj5Qex8z6xrVXmeUVAZP4MMGltsZ.jpg'}}, {'id': '64349943', 'firstName': 'B', 'lastName': 'L', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/64349943-31ZUTPAJWEGNN0K0.jpg'}}]}], 'summary': '4 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.4, 'ratingColor': 'FFC800', 'ratingSignals': 6, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 6, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 6, 'items': [{'id': '5ec844ee7589d10007a87ba2', 'createdAt': 1590183150, 'source': {'name': 'Yext Yext', 'url': 'http://yext.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/87388367_J3P_CfoBj9RWpmb9vY0MGXLBPfkoXu_WxNtpy7dx_eQ.png', 'width': 515, 'height': 397, 'user': {'id': '87388367', 'firstName': 'Yext', 'lastName': 'Y', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/blank_boy.png', 'default': True}}, 'visibility': 'public'}, {'id': '5456ff61498e566716fbdc3a', 'createdAt': 1414987617, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/4030648_pVuM1cNEX3sD3bJqqbBSGDAy5aep5YHWjgNKa0aDM3I.jpg', 'width': 960, 'height': 720, 'user': {'id': '4030648', 'firstName': 'Aubrey', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/ADAUONNBACMHP0MJ.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'description': "At 7-Eleven in Edmonton, we never close. Which is why we pride ourselves on being your neighbourhood go-to store - 24/7/365. Drop in for all your delicious wants and your tasty needs. We're home to everything you would expect from a convenience store and so much more...", 'storeId': '25120', 'page': {'pageInfo': {'links': {'count': 1, 'items': [{'url': 'http://t.co/p1Yxhabwq2'}]}}, 'user': {'id': '216484915', 'firstName': '7-El ...
# 6.4
# {'meta': {'code': 200, 'requestId': '5f2758eaf598007f30de1359'}, 'response': {'venue': {'id': '4b154feef964a520c7aa23e3', 'name': 'Tim Hortons', 'contact': {'phone': '7804065955', 'formattedPhone': '(780) 406-5955', 'twitter': 'timhortons'}, 'location': {'address': '420 Manning Crossing Nw', 'crossStreet': "near Smitty's & Safeway on 50th St. & 137th Ave", 'lat': 53.6007216613977, 'lng': -113.42092790524475, 'labeledLatLngs': [{'label': 'display', 'lat': 53.6007216613977, 'lng': -113.42092790524475}], 'postalCode': 'T5A 5A1', 'cc': 'CA', 'city': 'Edmonton', 'state': 'AB', 'country': 'Canada', 'formattedAddress': ["420 Manning Crossing Nw (near Smitty's & Safeway on 50th St. & 137th Ave)", 'Edmonton AB T5A 5A1', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/tim-hortons/4b154feef964a520c7aa23e3', 'categories': [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d148941735', 'name': 'Donut Shop', 'pluralName': 'Donut Shops', 'shortName': 'Donuts', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 4}, 'url': 'https://www.timhortons.ca/store-locator/store/restaurant_67897', 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 10, 'groups': [{'type': 'others', 'count': 10, 'items': []}], 'summary': '10 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.5, 'ratingColor': 'FFC800', 'ratingSignals': 18, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 7, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 7, 'items': [{'id': '5144e8b1e4b0fd5cb9939fca', 'createdAt': 1363470513, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/785985_zeBrJC2-F82g4bEipHJCLpbq1xZOd_4MZEcuAmjbNUM.jpg', 'width': 720, 'height': 720, 'user': {'id': '785985', 'firstName': 'Monti', 'lastName': 'T', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/H4MILHPRDTCPNR0B.jpg'}}, 'visibility': 'public'}, {'id': '5cedbd9aa22db7002c4bbfce', 'createdAt': 1559084442, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/411484_VTBA2euvxXDfnbhEuPiTe8mocOkd2FDlVqcp2FUq_yY.jpg', 'width': 1440, 'height': 1920, 'user': {'id': '411484', 'firstName': 'Lisa', 'lastName': 'M', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/I021VDBSFDJ3TNY2.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'description': "Located at 420 Manning Crossing Nw, Edmonton, AB, Tim Hortons is the perfect place to go for great-tasting, freshly brewed coffee. Our coffee is made with 100% Arabica beans, sourced from the world's most renowned growing regions...", 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1259687918, 'tips': {'count': 4, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 4, 'items': [{'id': '4cb6bb8a589f236aa3a9393d', 'createdAt': 1287043978, 'text': 'tip: people leave unhelpful tips for this place.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4cb6bb8a589f236aa3a9393d', 'lang': 'en', 'likes': {'count': 2, 'groups': [{'type': 'others', 'count': 2, 'items': [{'id': '31569624', 'firstName': 'Brooke', 'lastName': 'T', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/31569624-J0YPVNNJDPEWZIXS.jpg'}}, {'id': '27478', 'firstName': 'Lori', 'lastName': 'M', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/4a71f43bb4de0.jpg'}}]}], 'summary': '2 likes'}, 'logView': True, 'agreeCount': 2, 'disagreeCount': 0, ...
# 6.5
# {'meta': {'code': 200, 'requestId': '5f27596c58005e361f50c7ff'}, 'response': {'venue': {'id': '4b213438f964a520313824e3', 'name': 'Second Cup', 'contact': {'phone': '7804875810', 'formattedPhone': '(780) 487-5810', 'twitter': 'secondcupcanada', 'facebook': '312899235844285', 'facebookName': 'Second Cup Coffee Co.'}, 'location': {'address': '222 Mayfield Common', 'lat': 53.5418658, 'lng': -113.6106924, 'labeledLatLngs': [{'label': 'display', 'lat': 53.5418658, 'lng': -113.6106924}], 'postalCode': 'T5P 4B3', 'cc': 'CA', 'city': 'Edmonton', 'state': 'AB', 'country': 'Canada', 'formattedAddress': ['222 Mayfield Common', 'Edmonton AB T5P 4B3', 'Canada']}, 'canonicalUrl': 'https://foursquare.com/v/second-cup/4b213438f964a520313824e3', 'categories': [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 5}, 'url': 'https://secondcup.com/location/mayfield-common', 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 10, 'groups': [{'type': 'others', 'count': 10, 'items': []}], 'summary': '10 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.2, 'ratingColor': 'C5DE35', 'ratingSignals': 16, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 7, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 7, 'items': [{'id': '51b9fdb1498e93dcf02619cf', 'createdAt': 1371143601, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/12623116_soJ8Dlya6AXFLZCchvgd30_eWhOGt55RPxtNWsadJAg.jpg', 'width': 959, 'height': 717, 'user': {'id': '12623116', 'firstName': 'Sheldon', 'lastName': 'K', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/12623116-31KZJAL4GRI5NI2M.jpg'}}, 'visibility': 'public'}, {'id': '5de7235a071f4c00071504ba', 'createdAt': 1575428954, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/13294354_RqM2XRHl09aY_AXpptIQiZNd1PVDGdSLqtri0UEfh6g.jpg', 'width': 1920, 'height': 1440, 'user': {'id': '13294354', 'firstName': 'Myra', 'lastName': 'M', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/R03ZTM4JKCBDXWQE.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'description': 'Second Cup Coffee Co.™ is Canada’s largest specialty coffee retailer. From our humble beginnings in 1975 as a kiosk in a shopping mall, selling only whole bean coffee, we have continued towards our goal of being the Canadian specialty coffee brand of choice.', 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1260467256, 'tips': {'count': 5, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 5, 'items': [{'id': '5a7d170dbcbf7a7d6c0e0236', 'createdAt': 1518147341, 'text': 'Friendly staff. Chocolate banana loaf is quite good. Vanilla bean latte is also pretty good!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5a7d170dbcbf7a7d6c0e0236', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '403142', 'firstName': 'Gezim', 'lastName': 'H', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/403142-CQUI5GVMBDJNUV13.jpg'}}, 'authorInteractionType': 'liked'}, {'id': '5714dbcd498e27874aa38573', 'createdAt': 1460984781, 'text': 'Key lime cheesecake! 🍰☕️', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5714dbcd498e27874aa38573', 'photo': {'id': '5714dbcf498e00f3263bdc85', 'createdAt': 1460984783, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefi ...
# 7.2

# %%
dfEdmonton['# of Coffee Shops'] = np.asarray(numCoffeeShopsList)
dfEdmonton['Top Coffee Shop Rating'] = np.asarray(topCoffeeShopRatings)
dfEdmonton
# Out:
# <ipython-input-625-a91a6d3696b2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfEdmonton['# of Coffee Shops'] = np.asarray(numCoffeeShopsList)
# <ipython-input-625-a91a6d3696b2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfEdmonton['Top Coffee Shop Rating'] = np.asarray(topCoffeeShopRatings)
#                  Neighborhood   Latitude   Longitude  # of Coffee Shops  \
# 0                Abbottsfield  53.574115 -113.390517                  3
# 1                      Albany  53.632445 -113.553063                  3
# 2              Alberta Avenue  53.568277 -113.485870                  4
# 3     Alberta Park Industrial  53.566398 -113.597696                  3
# 4                  Aldergrove  53.517488 -113.649075                  1
# ..                        ...        ...         ...                ...
# 396                 Woodcroft  53.565543 -113.557051                  6
# 397  Yellowhead Corridor East  53.581239 -113.459361                  3
# 398  Yellowhead Corridor West  53.582963 -113.529320                  1
# 399                      York  53.603784 -113.429378                  5
# 400     Youngstown Industrial  53.549405 -113.612230                  3
#
#      Top Coffee Shop Rating
# 0                       6.2
# 1                       6.7
# 2                       8.2
# 3                       5.9
# 4                       NaN
# ..                      ...
# 396                     8.0
# 397                     NaN
# 398                     6.4
# 399                     6.5
# 400                     7.2
#
# [401 rows x 5 columns]

# %%
#fill neighborhoods with >0 cafes but no reviews with the city-wide average rating
dfEdmonton.fillna(dfEdmonton['Top Coffee Shop Rating'].mean(), inplace=True)

#give 0 rating to neighborhoods with 0 cafes
dfEdmonton['Top Coffee Shop Rating'].mask(dfEdmonton['# of Coffee Shops'] == 0, 0.0, inplace=True)

dfEdmonton.head(10)
# Out:
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:4311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py:8992: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._where(
#               Neighborhood   Latitude   Longitude  # of Coffee Shops  \
# 0             Abbottsfield  53.574115 -113.390517                  3
# 1                   Albany  53.632445 -113.553063                  3
# 2           Alberta Avenue  53.568277 -113.485870                  4
# 3  Alberta Park Industrial  53.566398 -113.597696                  3
# 4               Aldergrove  53.517488 -113.649075                  1
# 5                   Allard  53.401130 -113.524539                  2
# 6                Allendale  53.502473 -113.504723                  2
# 7                Ambleside  53.431306 -113.590535                  2
# 8           Anthony Henday  53.532513 -113.657309                  0
# 9  Anthony Henday Big Lake  53.590367 -113.643980                  0
#
#    Top Coffee Shop Rating
# 0                6.200000
# 1                6.700000
# 2                8.200000
# 3                5.900000
# 4                6.814453
# 5                6.600000
# 6                5.700000
# 7                6.800000
# 8                0.000000
# 9                0.000000

# %%
edmonton_grouped_clustering = dfEdmonton.drop(columns = ['Cluster Labels', '# of Coffee Shops','Neighborhood','Latitude', 'Longitude'])
edmonton_grouped_clustering.head()
# Out:
#    Top Coffee Shop Rating
# 0                6.200000
# 1                6.700000
# 2                8.200000
# 3                5.900000
# 4                6.814453

# %%
from sklearn.cluster import KMeans

# set number of clusters
kclusters = 4


# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(edmonton_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 3, 2, 0, 3, 3, 0, 3, 1, 1])

# %%
# add clustering labels
dfEdmonton.drop(columns = 'Cluster Labels', inplace=True)
dfEdmonton.insert(0, 'Cluster Labels', kmeans.labels_)
dfEdmonton.head()
# Out:
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:4157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#    Cluster Labels             Neighborhood   Latitude   Longitude  \
# 0               0             Abbottsfield  53.574115 -113.390517
# 1               3                   Albany  53.632445 -113.553063
# 2               2           Alberta Avenue  53.568277 -113.485870
# 3               0  Alberta Park Industrial  53.566398 -113.597696
# 4               3               Aldergrove  53.517488 -113.649075
#
#    # of Coffee Shops  Top Coffee Shop Rating
# 0                  3                6.200000
# 1                  3                6.700000
# 2                  4                8.200000
# 3                  3                5.900000
# 4                  1                6.814453

# %%
dfEdmonton.groupby(['Cluster Labels']).mean()
# Out:
#                  Latitude   Longitude  # of Coffee Shops  \
# Cluster Labels
# 0               53.539395 -113.501835           2.739496
# 1               53.517164 -113.521855           0.000000
# 2               53.513375 -113.510006           7.140351
# 3               53.524297 -113.526241           3.401575
#
#                 Top Coffee Shop Rating
# Cluster Labels
# 0                             6.200840
# 1                             0.000000
# 2                             8.047368
# 3                             6.836057

# %%
dfEdmonton.describe()
# Out:
#        Cluster Labels    Latitude   Longitude  # of Coffee Shops  \
# count      401.000000  401.000000  401.000000         401.000000
# mean         1.478803   53.525482 -113.515619           2.905237
# std          1.216624    0.066111    0.088071           3.395732
# min          0.000000   53.365261 -113.703122           0.000000
# 25%          0.000000   53.472776 -113.584271           1.000000
# 50%          1.000000   53.526059 -113.513574           2.000000
# 75%          3.000000   53.577381 -113.447312           4.000000
# max          3.000000   53.684593 -113.283408          20.000000
#
#        Top Coffee Shop Rating
# count              401.000000
# mean                 5.149076
# std                  2.994968
# min                  0.000000
# 25%                  5.600000
# 50%                  6.400000
# 75%                  6.814453
# max                  9.000000

# %%
dfEdmonton.loc[dfEdmonton['# of Coffee Shops'] == 0]
# Out:
#      Cluster Labels                       Neighborhood   Latitude   Longitude  \
# 8                 1                     Anthony Henday  53.532513 -113.657309
# 9                 1            Anthony Henday Big Lake  53.590367 -113.643980
# 10                1         Anthony Henday Castledowns  53.644316 -113.511064
# 11                1           Anthony Henday Clareview  53.616907 -113.361466
# 12                1         Anthony Henday Energy Park  53.638137 -113.415134
# ..              ...                                ...        ...         ...
# 386               1        Whitemud Creek Ravine North  53.488937 -113.558943
# 387               1        Whitemud Creek Ravine South  53.466980 -113.554507
# 388               1  Whitemud Creek Ravine Twin Brooks  53.443219 -113.550651
# 392               1                    Windermere Area  53.400125 -113.646064
# 394               1    Winterburn Industrial Area East  53.557185 -113.670078
#
#      # of Coffee Shops  Top Coffee Shop Rating
# 8                    0                     0.0
# 9                    0                     0.0
# 10                   0                     0.0
# 11                   0                     0.0
# 12                   0                     0.0
# ..                 ...                     ...
# 386                  0                     0.0
# 387                  0                     0.0
# 388                  0                     0.0
# 392                  0                     0.0
# 394                  0                     0.0
#
# [98 rows x 6 columns]

# %%
dfEdmonton.loc[dfEdmonton['# of Coffee Shops'] > 6].describe()
# Out:
#        Cluster Labels   Latitude   Longitude  # of Coffee Shops  \
# count       30.000000  30.000000   30.000000          30.000000
# mean         2.366667  53.533223 -113.526498          12.133333
# std          0.490133   0.029173    0.050193           4.454624
# min          2.000000  53.445434 -113.623939           7.000000
# 25%          2.000000  53.518935 -113.539077           8.000000
# 50%          2.000000  53.535203 -113.509513          11.500000
# 75%          3.000000  53.544673 -113.495309          15.750000
# max          3.000000  53.604276 -113.455263          20.000000
#
#        Top Coffee Shop Rating
# count               30.000000
# mean                 7.723333
# std                  0.655840
# min                  6.600000
# 25%                  7.200000
# 50%                  7.850000
# 75%                  8.150000
# max                  9.000000

# %%
topCoffeeShopRatings.count(np.nan)
# Out:
# 145

# %%
dfEdmonton["Cluster Labels"] = dfEdmonton["Cluster Labels"].fillna(-1).astype('Int64')

# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
# Out:
# <ipython-input-657-4a47f05f4d85>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfEdmonton["Cluster Labels"] = dfEdmonton["Cluster Labels"].fillna(-1).astype('Int64')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-657-4a47f05f4d85> in <module>
#       8 ys = [i + x + (i*x)**2 for i in range(kclusters)]
#       9 colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
# ---> 10 rainbow = [colors.rgb2hex(i) for i in colors_array]
#
# <ipython-input-657-4a47f05f4d85> in <listcomp>(.0)
#       8 ys = [i + x + (i*x)**2 for i in range(kclusters)]
#       9 colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
# ---> 10 rainbow = [colors.rgb2hex(i) for i in colors_array]
#
# AttributeError: 'numpy.ndarray' object has no attribute 'rgb2hex'

# %%
# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(dfEdmonton['Latitude'], dfEdmonton['Longitude'], dfEdmonton['Neighborhood'], dfEdmonton['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import matplotlib.pyplot as plt # plotting library

# backend for rendering plots within the browser
# %matplotlib inline

# %%
x1 = np.asarray(dfEdmonton['# of Coffee Shops'])
x2 = np.asarray(dfEdmonton['Top Coffee Shop Rating'])
colors = np.asarray(dfEdmonton['Cluster Labels'])
plt.scatter(x1, x2, s=50, c= colors)
plt.show()
